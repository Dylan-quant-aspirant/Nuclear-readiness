# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylan-quant-aspirant/Nuclear-readiness/blob/main/Nuclear_Earth_SetUp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

base_path = "/content/drive/MyDrive/Nuclear_Earth"
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-537287876.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 base_path = "/content/drive/MyDrive/Nuclear_Earth"
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
# ...

# %%
import pandas as pd

data = {
    'reactor_type': ['PWR', 'BWR', 'CANDU', 'HTGR', 'SMR'],
    'cooling': ['water', 'water', 'heavy_water', 'gas', 'flexible'],
    'seismic_tolerance': ['medium', 'low', 'medium', 'high', 'very_high'],
    'water_requirement': ['high', 'high', 'medium', 'low', 'low'],
    'power_output_MW': [1200, 1100, 700, 600, 300],
    'deployment_cost_M$/MW': [6, 5.8, 5.5, 4.8, 4.5],
    'construction_time_years': [6, 6, 5, 5, 3],
    'grid_flexibility': ['low', 'low', 'medium', 'high', 'high']
}

df = pd.DataFrame(data)
path = f"{base_path}/data/reactor_profiles.csv"
df.to_csv(path, index=False)
print("Saved:", path)

# !apt-get install tree

# !tree -L 3 /content/nuclear-earth
# Out:
# Saved: /content/nuclear-earth/data/reactor_profiles.csv
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (101 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 125081 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content/nuclear-earth
# ├── data
# │   ├── processed
# │   ├── raw
# │   └── reactor_profiles.csv
# ├── docs
# │   ├── data_features.md
# │   ├── methodology.md
# │   └── project_goals.md
# ...

# %%
import os

# Define root and sub-folders
base_path = "/content/nuclear-earth"
subfolders = [
    "data/raw",
    "data/processed",
    "model",
    "visualization",
    "webapp",
    "docs"
]

# Make all folders
for folder in subfolders:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

print("Folders created under:", base_path)

open(f"{base_path}/README.md", "w").write("# Nuclear Earth Project\n")
open(f"{base_path}/docs/project_goals.md", "w").write("Project goals go here.\n")
open(f"{base_path}/docs/data_features.md", "w").write("List of data features.\n")
open(f"{base_path}/docs/methodology.md", "w").write("Model pipeline.\n")
print("Placeholder docs created.")
# Out:
# Folders created under: /content/nuclear-earth
# Placeholder docs created.
